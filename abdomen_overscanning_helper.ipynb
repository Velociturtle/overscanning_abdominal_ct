# %%
from abdominal_overscan import caudal, cranial, metrics, mp4_preview, figures

# %%
caudal.run_batch(num_workers=1)  # increase if parallel processing/GPU available

# %%
cranial.run_batch(num_workers=1)  # increase if parallel processing/GPU available

# %%
metrics.generate_summary()

# %%
mp4_preview.run_all()

# %%
figures.generate_all()
