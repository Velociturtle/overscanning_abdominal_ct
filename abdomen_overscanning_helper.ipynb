# %%
import abdominal_overscan.config as config
import abdominal_overscan.caudal as caudal
import abdominal_overscan.cranial as cranial
import abdominal_overscan.mp4_preview as mp4_preview
import abdominal_overscan.metrics as metrics
import abdominal_overscan.figures as figures

# %%
caudal.run_batch()

# %%
cranial.run_batch()

# %%
# mp4_preview generates videos
# mp4_preview.main() if callable

# %%
# stats summary
# stats_summary.main() if callable

# %%
# plotting figures
# plotting.main() if callable
